# %%
# !nvidia-smi
# Out:
# Tue Mar  7 03:52:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    50W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !python --version
# !pip install --pre torch torchtext -f https://download.pytorch.org/whl/nightly/cpu/torch_nightly.html
# !pip install transformers --quiet
# !pip install pytorch-lightning --quiet
# !pip install https://github.com/PyTorchLightning/pytorch-lightning/releases/download/1.2.6/pytorch-lightning-1.2.6.tar.gz  --quiet
# Out:
# Python 3.9.16
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 87.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 75.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 24.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.6/715.6 KB 40.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 42.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 32.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 22.0 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np

from tqdm.auto import tqdm

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from transformers import BertTokenizerFast as BertTokenizer, BertModel, AdamW, get_linear_schedule_with_warmup

import pytorch_lightning as pl
from pytorch_lightning.metrics.functional import accuracy, f1, auroc
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, multilabel_confusion_matrix
from sklearn.model_selection import KFold

import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

RANDOM_SEED = 42
pl.seed_everything(RANDOM_SEED)

# %% [markdown]
# # Data

# %%
# !gdown --id 1c7t0jj4b1ORuQnL7hAFet8Vek-Oj00pw
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1c7t0jj4b1ORuQnL7hAFet8Vek-Oj00pw
# To: /content/app_reviews.csv
# 100% 603k/603k [00:00<00:00, 104MB/s]

# %%
df = pd.read_csv("app_reviews.csv")
df.head()
# Out:
#    id                                             review              class
# 0   1  Besides the occasional crash, this is an amazi...  problem discovery
# 1   2  This could be a great app if it was predictabl...  problem discovery
# 2   3  I can't open since the last 2 updates Pop-ups ...  problem discovery
# 3   4  Use to love this app but it's not working afte...  problem discovery
# 4   5  Urrrrm\tAfter my third re installing, it final...  problem discovery

# %%
df[df['class'] == "user experience"]
# Out:
#         id                                             review            class
# 3084  3085  Urrrrm\tAfter my third re installing, it final...  user experience
# 3085  3086  Does exactly what it says on the tin\tEffecien...  user experience
# 3086  3087  Best of what's available\tI've purchased a few...  user experience
# 3087  3088  Finally an Office Suite which works great\tI h...  user experience
# 3088  3089  Pretty good!\tI've edited many photos using th...  user experience
# ...    ...                                                ...              ...
# 3686  3687  Loved this app from jump!\tHave never had any ...  user experience
# 3687  3688  Best app\tCan always edit my pics and they wil...  user experience
# 3688  3689       Awesome\tpics art is my only app for editing  user experience
# 3689  3690  5star!!!!!\tI love it! ! Sumtime hate it catch...  user experience
# 3690  3691  Favourite hands down for photo editing ?\tEasy...  user experience
#
# [607 rows x 3 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# remove info giving class from dataset

# %%
df = df[df['class'] != "information seeking"]

# %%
train_df, val_df = train_test_split(df, test_size=0.25)
train_df.shape, val_df.shape
# Out:
# ((3735, 3), (1245, 3))

# %% [markdown]
# 75 - 25 % split (training size - testing size)

# %% [markdown]
# ## Distrubution of Labels

# %% [markdown]
# Let's look at the distribution of the labels:

# %%
CLASS_LABELS = df["class"].unique().tolist()
# CLASS_LABELS
fig = plt.figure(figsize=(15, 6))
y = [(train_df['class'] == label).sum() for label in CLASS_LABELS]
print(y)
# ax.bar(CLASS_LABELS, y)
plt.bar(CLASS_LABELS, y)
plt.xlabel("Class")
plt.ylabel("Number of Reviews")
plt.title("Distribution of Reviews")
plt.show()
# Out:
# [635, 1850, 337, 466, 447]

# %% [markdown]
# We have a server imbalance, we carry out undersamppling. To combat this, we'll sample *15,000* examples from the clean comments and create a new training set:

# %% [markdown]
# remove information seeking, take sample of all classes of len('feature request') (342 samples)

# %%
pd_train = train_df[train_df['class']=="problem discovery"]
rating_train = train_df[train_df['class']=="rating"]
feature_train = train_df[train_df['class']=="feature request"]
user_experience_train = train_df[train_df['class']=="user experience"]
info_giving_train = train_df[train_df['class']=="information giving"]

no_samples = len(feature_train)
no_samples
# Out:
# 337

# %%
train_df = pd.concat([
  pd_train.sample(no_samples),
  rating_train.sample(no_samples),
  feature_train,
  user_experience_train.sample(no_samples),
  info_giving_train.sample(no_samples)
])

train_df.shape, val_df.shape
# Out:
# ((1685, 3), (1245, 3))

# %%
train_df
# Out:
#          id                                             review  \
# 4199  17873                                     Please fix it!
# 213     214  Was I the only one to ever report this problem...
# 4788  14344  Although sometimes it crashes on me, the solut...
# 265     266  Nice going. I loved this app. You could match ...
# 3782   3875      Recent update causes Evernote on iOS to fail.
# ...     ...                                                ...
# 4764  14217                   Does everything I need it to do!
# 4842  14804  I did not get the idea of this app at first bu...
# 3974  16830                         App never crashes anymore.
# 3884  16446  It  s cool how you can save the things you lik...
# 4039  17301  I do wish, with all the new updates, they made...
#
#                    class
# 4199   problem discovery
# 213    problem discovery
# 4788   problem discovery
# 265    problem discovery
# 3782   problem discovery
# ...                  ...
# 4764  information giving
# 4842  information giving
# 3974  information giving
# 3884  information giving
# 4039  information giving
#
# [1685 rows x 3 columns]

# %%
CLASS_LABELS = df["class"].unique().tolist()
# CLASS_LABELS
fig = plt.figure(figsize=(15, 6))
y = [(train_df['class'] == label).sum() for label in CLASS_LABELS]
print(y)
# ax.bar(CLASS_LABELS, y)
plt.bar(CLASS_LABELS, y)
plt.xlabel("Class")
plt.ylabel("Number of Reviews")
plt.title("Distribution of Reviews")
plt.show()
# Out:
# [337, 337, 337, 337, 337]

# %% [markdown]
# Now we have an equal representation of samples from each set

# %% [markdown]
# ## Tokenization
# We need to convert the raw text into a list of tokens. For that, we'll use the built-in BertTokenizer:

# %%
BERT_MODEL_NAME = 'bert-base-cased'
tokenizer = BertTokenizer.from_pretrained(BERT_MODEL_NAME)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %% [markdown]
# We need to specify the maximum number of tokens when encoding (512 is the maximum we can do). Let's check the number of tokens per comment:

# %%
token_counts = []

for _, row in train_df.iterrows():
  token_count = len(tokenizer.encode(
    row["review"], 
    max_length=512, 
    truncation=True
  ))
  token_counts.append(token_count)

# %%
sns.histplot(token_counts)
plt.xlabel("Number of Tokens Per Comment")
plt.xlim([0, 512]);

# %% [markdown]
# Most of the reviews contain less than 200 tokens and a maximum of ~400 Tokens. Therfore, setting the MAX TOKEN COUNT to 512 (default value) will be a waste of storage and processing resourceses.

# %%
MAX_TOKEN_COUNT = 400

# %% [markdown]
# ## PyTorch Dataset

# %% [markdown]
# We'll wrap the tokenization process in a PyTorch Dataset, along with converting the labels to tensors:

# %% [markdown]
# Before we begin, a single class label need to be converted into a float vector.

# %%
def label_vector(review_label):
  vector = {label:0 for label in CLASS_LABELS}
  vector[review_label]=1
  return list(vector.values())

# %%
class AppReviewDataset(Dataset):
  def __init__(self, data: pd.DataFrame, tokenizer: BertTokenizer, max_token_len: int=128):
    self.data = data
    self.tokenizer = tokenizer
    self.max_token_len = max_token_len

  def __len__(self):
    return len(self.data)
  
  ## return encoding of review
  def __getitem__ (self, index: int):
    data_row = self.data.iloc[index]
    review = data_row['review']
    label = data_row['class']
    encoding = self.tokenizer.encode_plus(
        review,
        add_special_tokens=True,
        max_length=self.max_token_len,
        return_token_type_ids=False,
        padding="max_length",
        truncation=True,
        return_attention_mask=True,
        return_tensors="pt"
    )

    return dict(
        review=review,
        input_ids=encoding["input_ids"].flatten(),
        attention_mask=encoding["attention_mask"].flatten(),
        labels=torch.FloatTensor(label_vector(label))
    )

# %% [markdown]
# ## Load BERT model

# %%
bert_model = BertModel.from_pretrained(BERT_MODEL_NAME, return_dict=True)
# Out:
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# The larger version of BERT has more attention heads and a larger hidden size.
#
# The final step is to wrap our dataset into a lightningDataModule

# %%
class AppReviewDataModule(pl.LightningDataModule):
  def __init__(self, train_df, test_df, tokenizer, batch_size=8, max_token_len=128):
    super().__init__()
    self.train_df = train_df
    self.test_df = test_df
    self.tokenizer = tokenizer
    self.batch_size = batch_size
    self.max_token_len = max_token_len

  # create dataset for each of the training and test sets
  def setup(self, stage=None):
    self.train_dataset = AppReviewDataset(
        self.train_df,
        self.tokenizer,
        self.max_token_len
    )
    self.test_dataset = AppReviewDataset(
        self.test_df,
        self.tokenizer,
        self.max_token_len
    )

  def train_dataloader(self):
    return DataLoader(
        self.train_dataset,
        batch_size=self.batch_size,
        shuffle=True,
        num_workers=2
    )
    
  # make predictions on a single example (single batch size)
  def val_dataloader(self):
    return DataLoader(
        self.test_dataset,
        batch_size=self.batch_size,
        num_workers=2
    )
  
  def test_dataloader(self):
    return DataLoader(
        self.test_dataset,
        batch_size=self.batch_size,
        num_workers=2
    )

# %% [markdown]
# AppReviewDataModule encapsulates all data loading logic and returns the necessary data loaders. Let’s create an instance of our data module:

# %% [markdown]
# # Model
#
# The model will use a pre-trained BertModel and a linear layer to convert the BERT representation to a classification task. This will all be backed in a LightningModule

# %%
from torch.optim import lr_scheduler
class AppReviewTagger(pl.LightningModule):
  def __init__(self, n_classes: int, n_training_steps=None, n_warmup_steps=None):
    super().__init__()
    self.bert = BertModel.from_pretrained(BERT_MODEL_NAME, return_dict=True)
    # classifier: serve as a way to get the output of the BERT model and convert those into the num of classes which we want to predict
    self.classifier = nn.Linear(self.bert.config.hidden_size, n_classes)
    self.n_training_steps = n_training_steps
    self.n_warmup_steps = n_warmup_steps
    # This criterion computes the cross entropy loss between input logits and target
    self.criterion = nn.BCELoss()

  def forward(self, input_ids, attention_mask, labels=None):
    output = self.bert(input_ids, attention_mask=attention_mask)
    # run linear layer ontop of the output
    output = self.classifier(output.pooler_output)
    # apply sigmoid function
    output = torch.sigmoid(output)
    loss = 0
    if labels is not None:
      loss = self.criterion(output, labels)
    return loss, output

  def training_step(self, batch, batch_idx):
    input_ids = batch['input_ids']
    attention_mask = batch['attention_mask']
    labels = batch['labels']
    loss, outputs = self.forward(input_ids, attention_mask, labels)
    # output training loss
    self.log("train_loss", loss, prog_bar=True, logger=True)
    return {"loss": loss, "predictions": outputs, "labels": labels}

  def validation_step(self, batch, batch_idx):
    input_ids = batch['input_ids']
    attention_mask = batch['attention_mask']
    labels = batch['labels']
    loss, outputs = self.forward(input_ids, attention_mask, labels)
    # output training loss
    self.log("val_loss", loss, prog_bar=True, logger=True)
    return loss
  
  def test_step(self, batch, batch_idx):
    input_ids = batch['input_ids']
    attention_mask = batch['attention_mask']
    labels = batch['labels']
    loss, outputs = self.forward(input_ids, attention_mask, labels)
    # output training loss
    self.log("test_loss", loss, prog_bar=True, logger=True)
    return loss

  def training_epoch_end(self, outputs):
    labels = []
    predictions = []
    
    for output in outputs:
      for out_labels in output['labels'].detach().cpu():
        labels.append(out_labels)

      for out_predictions in output['predictions'].detach().cpu():
        predictions.append(out_predictions)

    # convert to tourch
    labels = torch.stack(labels).int()
    predictions = torch.stack(predictions)

    # Calculate ROC score for each tag
    for i, name in enumerate(CLASS_LABELS):
      class_roc_auc = auroc(predictions[:, i], labels[:, i])
      self.logger.experiment.add_scalar(f"{name}_roc_auc/Train", class_roc_auc, self.current_epoch)

  # configer optimisers and learning rate scheduler
  def configure_optimizers(self):
    # fine tuning recomendations from original BERT paper
    optimizer = AdamW(self.parameters(), lr=2e-5)
  
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=self.n_warmup_steps,
        num_training_steps=self.n_training_steps
    )

    # return a list of optimisers and schedulers
    return dict(
        optimizer=optimizer,
        lr_scheduler=dict(
            scheduler=scheduler,
            interval='step'
        )
    )

# %% [markdown]
# Most of the implementation is just a boilerplate. Two points of interest are the wat the optimizer is configured and calculating the area under ROC. We'll dive a bit deep into those next.

# %% [markdown]
# ##Using an optimiser

# %% [markdown]
# We simulate 100 training steps and tell the scheduler to warm up for the first 20. The learning rate grows to the initial fixed value of 0.001 during the warm-up and then goes down (linearly) to 0.
#
# To use the scheduler, we need to calculate the number of training and warm-up steps. The number of training steps per epoch is equal to number of training examples / batch size. The number of total training steps is training steps per epoch * number of epochs:

# %% [markdown]
# # Training

# %% [markdown]
# The beauty of PyTorch Lightning is that you can build a standard pipeline and train every model you might imagine. I prefer to use at least 3 components.
#
# Checkpointing that saves the best model (based on validation loss):

# %% [markdown]
# Log the progress in TensorBoard:

# %% [markdown]
# And early stopping triggers when the loss hasn’t improved for the last 2 epochs (you might want to remove/reconsider this when training on real-world projects):

# %% [markdown]
# # Train with K-fold Cross Validation

# %%
# split dataset into k-folds
df
# Out:
#           id                                             review  \
# 0          1  Besides the occasional crash, this is an amazi...
# 1          2  This could be a great app if it was predictabl...
# 2          3  I can't open since the last 2 updates Pop-ups ...
# 3          4  Use to love this app but it's not working afte...
# 4          5  Urrrrm\tAfter my third re installing, it final...
# ...      ...                                                ...
# 5075  143450  Bakwas application\tAlways not responding prob...
# 5076  143476                             Ma fav\tI just love it
# 5077  143509    But the problem is very slow running to update.
# 5078  143513  But I  d suggest two important features which ...
# 5080  143513                         This must be added common.
#
#                    class
# 0      problem discovery
# 1      problem discovery
# 2      problem discovery
# 3      problem discovery
# 4      problem discovery
# ...                  ...
# 5075   problem discovery
# 5076  information giving
# 5077   problem discovery
# 5078     feature request
# 5080     feature request
#
# [4980 rows x 3 columns]

# %%
CLASS_LABELS = df["class"].unique().tolist()
# CLASS_LABELS
fig = plt.figure(figsize=(15, 6))
y = [(train_df['class'] == label).sum() for label in CLASS_LABELS]
print(y)
# ax.bar(CLASS_LABELS, y)
plt.bar(CLASS_LABELS, y)
plt.xlabel("Class")
plt.ylabel("Number of Reviews")
plt.title("Distribution of Reviews")
plt.show()
# Out:
# [337, 337, 337, 337, 337]

# %%
N_EPOCHS = 10
BATCH_SIZE = 8
MAX_TOKEN_COUNT = 400
THRESHOLD = 0.5
BERT_MODEL_NAME = 'bert-base-cased'
tokenizer = BertTokenizer.from_pretrained(BERT_MODEL_NAME)

accuracies = []
AUROC_evalute = []

kFold = KFold(n_splits=5, shuffle=True)
for fold_number, (train_index, test_index) in enumerate(kFold.split(df)):
  train_df = df.iloc[train_index]
  val_df = df.iloc[test_index]

  data_module = AppReviewDataModule(
      train_df,
      val_df,
      tokenizer,
      batch_size=BATCH_SIZE,
      max_token_len=MAX_TOKEN_COUNT
  )

  steps_per_epoch = len(train_df) // BATCH_SIZE
  total_training_steps = steps_per_epoch * N_EPOCHS
  warmup_steps = total_training_steps // 5

  model = AppReviewTagger(
    n_classes=len(CLASS_LABELS),
    n_warmup_steps=warmup_steps,
    n_training_steps=total_training_steps
  )
  
  checkpoint_callback = ModelCheckpoint(
    dirpath="Fold-{0}".format(fold_number),
    filename="best-checkpoint",
    save_top_k=1,
    verbose=True,
    monitor="val_loss",
    mode="min"
  )
  logger = TensorBoardLogger("lightning_logs", name="app-comments")
  early_stopping_callback = EarlyStopping(monitor='val_loss', patience=2)

  trainer = pl.Trainer(
    logger=logger,
    checkpoint_callback=checkpoint_callback,
    callbacks=[early_stopping_callback],
    max_epochs=N_EPOCHS,
    gpus=1,
    progress_bar_refresh_rate=30
  )

  trainer.fit(model, data_module)
  trainer.test()

  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  # trained_model = model.to(device)

  val_dataset = AppReviewDataset(
    val_df,
    tokenizer,
    max_token_len=MAX_TOKEN_COUNT
  )

  predictions = []
  labels = []

  with torch.no_grad(): 
    for item in tqdm(val_dataset):
      _, prediction = model(
        item["input_ids"].unsqueeze(dim=0).to(device),
        item["attention_mask"].unsqueeze(dim=0).to(device)
      )
      predictions.append(prediction.flatten())
      labels.append(item["labels"].int())
    
  predictions = torch.stack(predictions).detach().cpu()
  labels = torch.stack(labels).detach().cpu()

  # store accuracy of each fold
  accuracies.append(accuracy(predictions, labels, threshold=THRESHOLD))
  print("fold-{0}: accuracy: {1}".format(fold_number, accuracy(predictions, labels, threshold=THRESHOLD)))

  # store auroc of each fold
  roc = {}
  print("AUROC per tag")
  for i, name in enumerate(CLASS_LABELS):
    tag_auroc = auroc(predictions[:, i], labels[:, i], pos_label=1)
    # print(f"{name}: {tag_auroc}")
    roc[name] = tag_auroc
  AUROC_evalute.append(roc)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# GPU available: True, used: True
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# TPU available: None, using: 0 TPU cores
# INFO:lightning:TPU available: None, using: 0 TPU cores
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# INFO:lightning:
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Validation sanity check: 0it [00:00, ?it/s]
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Training: 0it [00:00, ?it/s]
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: `pos_label` automatically set 1.
#   warnings.warn(*args, **kwargs)
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 497: val_loss reached 0.33804 (best 0.33804), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# Epoch 0, global step 497: val_loss reached 0.33804 (best 0.33804), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 0, global step 497: val_loss reached 0.33804 (best 0.33804), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 995: val_loss reached 0.30284 (best 0.30284), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# Epoch 1, global step 995: val_loss reached 0.30284 (best 0.30284), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 1, global step 995: val_loss reached 0.30284 (best 0.30284), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, global step 1493: val_loss reached 0.28293 (best 0.28293), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# Epoch 2, global step 1493: val_loss reached 0.28293 (best 0.28293), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 2, global step 1493: val_loss reached 0.28293 (best 0.28293), saving model to "/content/Fold-0/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, step 1991: val_loss was not in top 1
# Epoch 3, step 1991: val_loss was not in top 1
# INFO:lightning:Epoch 3, step 1991: val_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 4, step 2489: val_loss was not in top 1
# Epoch 4, step 2489: val_loss was not in top 1
# INFO:lightning:Epoch 4, step 2489: val_loss was not in top 1
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, test dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 0.28292739391326904}
# --------------------------------------------------------------------------------
#   0%|          | 0/996 [00:00<?, ?it/s]
# fold-0: accuracy: 0.8887550234794617
# AUROC per tag
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# GPU available: True, used: True
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# TPU available: None, using: 0 TPU cores
# INFO:lightning:TPU available: None, using: 0 TPU cores
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# INFO:lightning:
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 497: val_loss reached 0.37795 (best 0.37795), saving model to "/content/Fold-1/best-checkpoint.ckpt" as top 1
# Epoch 0, global step 497: val_loss reached 0.37795 (best 0.37795), saving model to "/content/Fold-1/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 0, global step 497: val_loss reached 0.37795 (best 0.37795), saving model to "/content/Fold-1/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 995: val_loss reached 0.30235 (best 0.30235), saving model to "/content/Fold-1/best-checkpoint.ckpt" as top 1
# Epoch 1, global step 995: val_loss reached 0.30235 (best 0.30235), saving model to "/content/Fold-1/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 1, global step 995: val_loss reached 0.30235 (best 0.30235), saving model to "/content/Fold-1/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, step 1493: val_loss was not in top 1
# Epoch 2, step 1493: val_loss was not in top 1
# INFO:lightning:Epoch 2, step 1493: val_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, step 1991: val_loss was not in top 1
# Epoch 3, step 1991: val_loss was not in top 1
# INFO:lightning:Epoch 3, step 1991: val_loss was not in top 1
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 0.30234619975090027}
# --------------------------------------------------------------------------------
#   0%|          | 0/996 [00:00<?, ?it/s]
# fold-1: accuracy: 0.8688755035400391
# AUROC per tag
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# GPU available: True, used: True
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# TPU available: None, using: 0 TPU cores
# INFO:lightning:TPU available: None, using: 0 TPU cores
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# INFO:lightning:
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 497: val_loss reached 0.35199 (best 0.35199), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# Epoch 0, global step 497: val_loss reached 0.35199 (best 0.35199), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 0, global step 497: val_loss reached 0.35199 (best 0.35199), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 995: val_loss reached 0.32390 (best 0.32390), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# Epoch 1, global step 995: val_loss reached 0.32390 (best 0.32390), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 1, global step 995: val_loss reached 0.32390 (best 0.32390), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, global step 1493: val_loss reached 0.30624 (best 0.30624), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# Epoch 2, global step 1493: val_loss reached 0.30624 (best 0.30624), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 2, global step 1493: val_loss reached 0.30624 (best 0.30624), saving model to "/content/Fold-2/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, step 1991: val_loss was not in top 1
# Epoch 3, step 1991: val_loss was not in top 1
# INFO:lightning:Epoch 3, step 1991: val_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 4, step 2489: val_loss was not in top 1
# Epoch 4, step 2489: val_loss was not in top 1
# INFO:lightning:Epoch 4, step 2489: val_loss was not in top 1
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 0.30624374747276306}
# --------------------------------------------------------------------------------
#   0%|          | 0/996 [00:00<?, ?it/s]
# fold-2: accuracy: 0.8913654685020447
# AUROC per tag
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# GPU available: True, used: True
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# TPU available: None, using: 0 TPU cores
# INFO:lightning:TPU available: None, using: 0 TPU cores
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# INFO:lightning:
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 497: val_loss reached 0.40204 (best 0.40204), saving model to "/content/Fold-3/best-checkpoint.ckpt" as top 1
# Epoch 0, global step 497: val_loss reached 0.40204 (best 0.40204), saving model to "/content/Fold-3/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 0, global step 497: val_loss reached 0.40204 (best 0.40204), saving model to "/content/Fold-3/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 995: val_loss reached 0.33802 (best 0.33802), saving model to "/content/Fold-3/best-checkpoint.ckpt" as top 1
# Epoch 1, global step 995: val_loss reached 0.33802 (best 0.33802), saving model to "/content/Fold-3/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 1, global step 995: val_loss reached 0.33802 (best 0.33802), saving model to "/content/Fold-3/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, step 1493: val_loss was not in top 1
# Epoch 2, step 1493: val_loss was not in top 1
# INFO:lightning:Epoch 2, step 1493: val_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, step 1991: val_loss was not in top 1
# Epoch 3, step 1991: val_loss was not in top 1
# INFO:lightning:Epoch 3, step 1991: val_loss was not in top 1
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 0.3380240201950073}
# --------------------------------------------------------------------------------
#   0%|          | 0/996 [00:00<?, ?it/s]
# fold-3: accuracy: 0.8883534073829651
# AUROC per tag
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# GPU available: True, used: True
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# TPU available: None, using: 0 TPU cores
# INFO:lightning:TPU available: None, using: 0 TPU cores
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
#
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# INFO:lightning:
#   | Name       | Type      | Params
# -----------------------------------------
# 0 | bert       | BertModel | 108 M
# 1 | classifier | Linear    | 3.8 K
# 2 | criterion  | BCELoss   | 0
# -----------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 433.256   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0, global step 497: val_loss reached 0.40802 (best 0.40802), saving model to "/content/Fold-4/best-checkpoint.ckpt" as top 1
# Epoch 0, global step 497: val_loss reached 0.40802 (best 0.40802), saving model to "/content/Fold-4/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 0, global step 497: val_loss reached 0.40802 (best 0.40802), saving model to "/content/Fold-4/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 1, global step 995: val_loss reached 0.28681 (best 0.28681), saving model to "/content/Fold-4/best-checkpoint.ckpt" as top 1
# Epoch 1, global step 995: val_loss reached 0.28681 (best 0.28681), saving model to "/content/Fold-4/best-checkpoint.ckpt" as top 1
# INFO:lightning:Epoch 1, global step 995: val_loss reached 0.28681 (best 0.28681), saving model to "/content/Fold-4/best-checkpoint.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 2, step 1493: val_loss was not in top 1
# Epoch 2, step 1493: val_loss was not in top 1
# INFO:lightning:Epoch 2, step 1493: val_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, step 1991: val_loss was not in top 1
# Epoch 3, step 1991: val_loss was not in top 1
# INFO:lightning:Epoch 3, step 1991: val_loss was not in top 1
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 0.2868105173110962}
# --------------------------------------------------------------------------------
#   0%|          | 0/996 [00:00<?, ?it/s]
# fold-4: accuracy: 0.8885542154312134
# AUROC per tag

# %%
accuracies, AUROC_evalute
# Out:
# ([tensor(0.8888),
#   tensor(0.8689),
#   tensor(0.8914),
#   tensor(0.8884),
#   tensor(0.8886)],
#  [{'problem discovery': tensor(0.9527),
#    'rating': tensor(0.9084),
#    'feature request': tensor(0.8915),
#    'user experience': tensor(0.8805),
#    'information giving': tensor(0.9475)},
#   {'problem discovery': tensor(0.9436),
#    'rating': tensor(0.9221),
#    'feature request': tensor(0.8952),
#    'user experience': tensor(0.8447),
#    'information giving': tensor(0.8976)},
#   {'problem discovery': tensor(0.9294),
#    'rating': tensor(0.9078),
#    'feature request': tensor(0.9162),
#    'user experience': tensor(0.8682),
#    'information giving': tensor(0.9713)},
#   {'problem discovery': tensor(0.9384),
#    'rating': tensor(0.9112),
#    'feature request': tensor(0.8660),
#    'user experience': tensor(0.8772),
#    'information giving': tensor(0.9505)},
#   {'problem discovery': tensor(0.9344),
#    'rating': tensor(0.9162),
#    'feature request': tensor(0.8915),
#    'user experience': tensor(0.8436),
#    'information giving': tensor(0.9507)}])

# %%
accuracies = np.array(accuracies)
np.mean(accuracies)
# Out:
# 0.8851808

# %%
AUROC_evalute[2]
# Out:
# {'problem discovery': tensor(0.9294),
#  'rating': tensor(0.9078),
#  'feature request': tensor(0.9162),
#  'user experience': tensor(0.8682),
#  'information giving': tensor(0.9713)}

# %% [markdown]
# The average accuracy across all 5 Folds is 0.89. The fold which produced the highest accuracy was Fold 2.

# %%
trained_model = AppReviewTagger.load_from_checkpoint(
  "./Fold-2/best-checkpoint.ckpt",
  n_classes=len(CLASS_LABELS)
)
trained_model.eval()
trained_model.freeze()
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
trained_model = trained_model.to(device)

val_dataset = AppReviewDataset(
  val_df,
  tokenizer,
  max_token_len=MAX_TOKEN_COUNT
)

predictions = []
labels = []

with torch.no_grad():
  for item in tqdm(val_dataset):
    _, prediction = trained_model(
      item["input_ids"].unsqueeze(dim=0).to(device),
      item["attention_mask"].unsqueeze(dim=0).to(device)
    )
    predictions.append(prediction.flatten())
    labels.append(item["labels"].int())
  
predictions = torch.stack(predictions).detach().cpu()
labels = torch.stack(labels).detach().cpu()
# Out:
#   0%|          | 0/996 [00:00<?, ?it/s]

# %%
accuracy(predictions, labels, threshold=THRESHOLD)
# Out:
# tensor(0.8886)

# %%
print("AUROC per tag")
for i, name in enumerate(CLASS_LABELS):
  tag_auroc = auroc(predictions[:, i], labels[:, i], pos_label=1)
  print(f"{name}: {tag_auroc}")
# Out:
# AUROC per tag
# problem discovery: 0.9861655831336975
# rating: 0.9716802835464478
# feature request: 0.9798250794410706
# user experience: 0.9333120584487915
# information giving: 0.9894985556602478

# %%
y_pred = predictions.numpy()
y_true = labels.numpy()

upper, lower = 1, 0

y_pred = np.where(y_pred > THRESHOLD, upper, lower)

print(classification_report(
  y_true,
  y_pred,
  target_names=CLASS_LABELS,
  zero_division=0
))
# Out:
#                     precision    recall  f1-score   support
#
#  problem discovery       0.88      0.93      0.91       180
#             rating       0.90      0.92      0.91       491
#    feature request       0.89      0.45      0.60        87
#    user experience       0.68      0.46      0.55       104
# information giving       0.93      0.96      0.95       134
#
#          micro avg       0.88      0.84      0.86       996
#          macro avg       0.86      0.74      0.78       996
#       weighted avg       0.88      0.84      0.85       996
#        samples avg       0.83      0.84      0.83       996

# %%
x_axis = np.arange(5)
y_axis = accuracies
average_y = [np.mean(y_axis)for i in range(5)]

fig = plt.figure(figsize=(10, 6))
plt.plot(x_axis, y_axis, label='Accuracy')
plt.plot(x_axis, average_y, label='Average')
plt.title('Accuracy Over Each Fold')
plt.xlabel('Fold Number')
plt.ylabel('Accuracy')
plt.legend(loc="lower right", prop={'size': 12})

plt.show()

# %%
CLASS_LABELS = df["class"].unique().tolist()

fig = plt.figure(figsize=(10, 6))
y = [AUROC_evalute[2][label] for label in CLASS_LABELS]
print(y)
# ax.bar(CLASS_LABELS, y)
plt.bar(CLASS_LABELS, y)
plt.ylim(0.8, 1)
plt.xlabel("Class")
plt.ylabel("Number of Reviews")
plt.title("Distribution of Reviews")
plt.show()
# Out:
# [tensor(0.9294), tensor(0.9078), tensor(0.9162), tensor(0.8682), tensor(0.9713)]
